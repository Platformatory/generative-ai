# %% [markdown]
# # Module 5A Quiz
#
# **Total**: 32 questions

# %% [markdown]
# ## Hour 2: Gen AI Fundamentals & AI Functions (Demo 2)
#
# ---

# %% [markdown]
# ### Q1.
#
# A Generative AI Engineer would like to build an application that can update a memo field that is about a paragraph long to just a single sentence gist that shows intent of the memo field, but fits into their application front end.
#
# With which Natural Language Processing task category should they evaluate potential LLMs for this application?
#
# **A.** text2text Generation
# **B.** Sentencizer
# **C.** Text Classification
# **D.** Summarization

# %%
answer(1)
# Out:
#   <details>
#   <summary><b>Q1 - Click to reveal answer</b></summary>
#   <p><b>Answer: D - Summarization</b></p>
#   <p><b>Explanation:</b> Condensing a paragraph into a single-sentence gist that captures intent is a summarization task. The LLM takes a longer input and produces a shorter version that captures the essential meaning. text2text Generation (A) is broader and includes translation, not just condensation. Sentencizer (B) splits text into sentences, it doesn't summarize. Text Classification (C) categorizes text into labels, it doesn't produce a summary.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/large-language-models/concept-ai-functions" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ---
#
# ### Q2.
#
# A Generative AI Engineer is building an LLM to generate article summaries in the form of a type of poem, such as a haiku, given the article content. However, the initial output from the LLM does not match the desired tone or style. Which approach will NOT improve the LLM's response?
#
# **A.** Provide the LLM with a prompt that explicitly instructs it to generate text in the desired tone and style
# **B.** Use a neutralizer to normalize the tone and style of the underlying documents
# **C.** Include few-shot examples in the prompt to the LLM
# **D.** Fine-tune the LLM on a dataset of desired tone and style

# %%
answer(2)
# Out:
#   <details>
#   <summary><b>Q2 - Click to reveal answer</b></summary>
#   <p><b>Answer: B</b></p>
#   <p><b>Explanation:</b> Normalizing the source document's tone does NOT help because the LLM generates its own text—the source document's tone is irrelevant to the output style. The LLM reads the content, not the style, of the source. Providing explicit prompt instructions (A), including few-shot examples (C), and fine-tuning (D) are all valid approaches to control the LLM's output tone and style.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/large-language-models/concept-ai-functions" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ## Hour 3: RAG Fundamentals & Document Processing (Demo 3)
#
# ---

# %% [markdown]
# ### Q3.
#
# A Generative AI Engineer is assessing the responses from a customer-facing GenAI application that they are developing to assist in selling automotive parts. The application requires the customer to explicitly input account_id and transaction_id to answer questions. After initial launch, the customer feedback was that the application did well on answering order and billing details, but failed to accurately answer shipping and expected arrival date questions.
#
# Which of the following approaches would improve the application's ability to answer these questions?
#
# **A.** Create a vector store that includes the company shipping policies and payment terms for all automotive parts
# **B.** Create a feature store table with transaction_id as primary key that is populated with invoice data and expected delivery date
# **C.** Provide examples data for expected arrival dates as a tuning dataset, then periodically fine-tune the model so that it has updated shipping information
# **D.** Amend the chat prompt to input when the order was placed and instruct the model to add 14 days to that as no shipping method is expected to exceed 14 days

# %%
answer(3)
# Out:
#   <details>
#   <summary><b>Q3 - Click to reveal answer</b></summary>
#   <p><b>Answer: B</b></p>
#   <p><b>Explanation:</b> The application needs structured delivery date data keyed by transaction_id. A feature store table provides exact lookup for specific transactions, while a vector store is for semantic search over unstructured content. Shipping policies in a vector store (A) would return general policy text, not specific delivery dates for specific orders. Fine-tuning (C) would require constant retraining. Adding 14 days (D) is unreliable as actual delivery times vary by location and shipping method.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/machine-learning/feature-store/" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ---
#
# ### Q4.
#
# A Generative AI Engineer is building a RAG application that will rely on context retrieved from source documents that have been scanned and saved as image files in formats like .jpeg or .png. They want to develop a solution using the least amount of lines of code.
#
# Which Python package should be used to extract the text from the source documents?
#
# **A.** beautifulsoup
# **B.** scrapy
# **C.** pytesseract
# **D.** pyquery

# %%
answer(4)
# Out:
#   <details>
#   <summary><b>Q4 - Click to reveal answer</b></summary>
#   <p><b>Answer: C - pytesseract</b></p>
#   <p><b>Explanation:</b> pytesseract is an OCR wrapper for the Tesseract engine that extracts text from scanned images (.jpeg, .png) with minimal code. beautifulsoup (A) is an HTML parser, not an OCR tool. scrapy (B) is a web scraping framework. pyquery (D) is a jQuery-like HTML querying library. For scanned images specifically, pytesseract is the correct choice. In production on Databricks, you would use ai_parse_document instead, but pytesseract is the correct third-party library answer.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/large-language-models/concept-ai-functions" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ---
#
# ### Q5.
#
# You fine-tuned an instruction model for your internal knowledge base, but it often fabricates answers. You want to reduce hallucinations without another fine-tune. What's the best next step?
#
# **A.** Introduce retrieval-augmented generation using a curated Vector Search index and include citations in the prompt
# **B.** Increase temperature to encourage more diverse reasoning
# **C.** Switch to a larger model only
# **D.** Remove system prompts to avoid bias

# %%
answer(5)
# Out:
#   <details>
#   <summary><b>Q5 - Click to reveal answer</b></summary>
#   <p><b>Answer: A</b></p>
#   <p><b>Explanation:</b> RAG grounds responses in retrieved facts from a curated Vector Search index, reducing hallucinations. Including citations in the prompt adds traceability and allows verification. Increasing temperature (B) would increase randomness and likely worsen hallucinations. Switching to a larger model (C) doesn't solve hallucination—it may hallucinate just as confidently. Removing system prompts (D) removes useful guidance that keeps the model on track.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/large-language-models/rag-concept" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ---
#
# ### Q6.
#
# A stakeholder wants the bot to answer only from approved sources and refuse otherwise, with a clear "I don't know" when evidence is weak. What's the best approach?
#
# **A.** Lower temperature and hope for the best
# **B.** Retrieval gating: require a minimum relevance threshold and include a refusal policy in the system prompt
# **C.** Increase top_p for diversity
# **D.** Use only embeddings without prompts

# %%
answer(6)
# Out:
#   <details>
#   <summary><b>Q6 - Click to reveal answer</b></summary>
#   <p><b>Answer: B</b></p>
#   <p><b>Explanation:</b> Retrieval gating requires a minimum relevance score before using retrieved context. If the best chunk's similarity is below a threshold, the system should refuse to answer ('I don't know') instead of guessing. A refusal policy in the system prompt explicitly instructs the model to say 'I don't know' when evidence is weak. Lowering temperature (A) reduces randomness but doesn't guarantee grounded answers. Increasing top_p (C) increases diversity, worsening the problem. Using only embeddings (D) without prompts removes the instruction to refuse.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/large-language-models/rag-concept" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ---
#
# ### Q7.
#
# Your PDF-heavy corpus includes long tables that are poorly parsed into text, hurting retrieval quality. What's the best path?
#
# **A.** Ignore tables and rely on the model
# **B.** Add a table-aware extraction step that preserves structure; store both text and structured table data with metadata for retrieval
# **C.** Increase chunk size to include entire tables in each chunk
# **D.** Use only OCR text

# %%
answer(7)
# Out:
#   <details>
#   <summary><b>Q7 - Click to reveal answer</b></summary>
#   <p><b>Answer: B</b></p>
#   <p><b>Explanation:</b> Table-aware extraction preserves the structure that plain OCR or text extraction loses. Tables in PDFs have rows, columns, and cell relationships that are destroyed when flattened to text. Storing both text and structured table data with metadata enables accurate retrieval of tabular content. Ignoring tables (A) loses critical information. Increasing chunk size to include entire tables (C) dilutes relevance and may exceed token limits. Using only OCR text (D) loses table structure entirely.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/large-language-models/concept-ai-functions" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ---
#
# ### Q8.
#
# A Generative AI Engineer is building a RAG application that answers questions about internal documents for the company SnoPen AI. The source documents may contain a significant amount of irrelevant content, such as advertisements, sports news, or entertainment news, or content about other companies.
#
# Which approach is advisable when building a RAG application to achieve this goal of filtering irrelevant information?
#
# **A.** Keep all articles because the RAG application needs to understand non-company content to avoid answering questions about them.
# **B.** Include in the system prompt that any information it sees will be about SnoPenAI, even if no data filtering is performed.
# **C.** Include in the system prompt that the application is not supposed to answer any questions unrelated to SnoPen AI.
# **D.** Consolidate all SnoPen AI related documents into a single chunk in the vector database.

# %%
answer(8)
# Out:
#   <details>
#   <summary><b>Q8 - Click to reveal answer</b></summary>
#   <p><b>Answer: C</b></p>
#   <p><b>Explanation:</b> A system prompt instruction to refuse unrelated questions is the simplest and most effective approach among the options. It directly instructs the model to stay on topic and decline off-topic questions. Keeping all articles (A) pollutes the index with irrelevant content. Telling the model all content is about SnoPenAI (B) is factually wrong and could cause hallucination. Consolidating into a single chunk (D) loses granularity and makes retrieval less precise.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/large-language-models/rag-concept" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ---
#
# ### Q9.
#
# A company has a typical RAG-enabled, customer-facing chatbot. Select the correct sequence of components a user's question goes through before the final output is returned.
#
# **A.** 1.embedding model, 2.vector search, 3.context-augmented prompt, 4.response-generating LLM
# **B.** 1.context-augmented prompt, 2.vector search, 3.embedding model, 4.response-generating LLM
# **C.** 1.response-generating LLM, 2.vector search, 3.context-augmented prompt, 4.embedding model
# **D.** 1.response-generating LLM, 2.context-augmented prompt, 3.vector search, 4.embedding model

# %%
answer(9)
# Out:
#   <details>
#   <summary><b>Q9 - Click to reveal answer</b></summary>
#   <p><b>Answer: A</b></p>
#   <p><b>Explanation:</b> The correct RAG flow is: (1) embed the user's query using the embedding model, (2) search the vector index for similar chunks using the embedded query, (3) augment the prompt with retrieved context, (4) generate the response with the LLM. Option B has the wrong order (context before search). Option C starts with the LLM. Option D also starts with the LLM.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/large-language-models/rag-concept" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ---
#
# ### Q10.
#
# A Generative AI Engineer is building a RAG application that will rely on context retrieved from source documents that are currently in PDF format. These PDFs can contain both text and images. They want to develop a solution using the least amount of lines of code.
#
# Which Python package should be used to extract the text from the source documents?
#
# **A.** flask
# **B.** beautifulsoup
# **C.** unstructured
# **D.** numpy

# %%
answer(10)
# Out:
#   <details>
#   <summary><b>Q10 - Click to reveal answer</b></summary>
#   <p><b>Answer: C - unstructured</b></p>
#   <p><b>Explanation:</b> The unstructured library handles mixed-format PDFs (containing both text and images) with minimal code. flask (A) is a web framework, not a document processing tool. beautifulsoup (B) is for HTML parsing. numpy (D) is for numerical computing. For PDFs with mixed text and images, unstructured is the correct choice. For scanned images only (.jpeg, .png), pytesseract would be better. In production on Databricks, you would use ai_parse_document instead.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/large-language-models/concept-ai-functions" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ## Hour 3: AI Search, Embeddings & Vector Search (Demo 3)
#
# ---

# %% [markdown]
# ### Q11.
#
# A Generative AI Engineer is loading 150 million embeddings into a vector database that takes a maximum of 100 million. Which TWO actions can they take to reduce the record count?
#
# **A.** Increase the document chunk size
# **B.** Decrease the overlap between chunks
# **C.** Decrease the document chunk size
# **D.** Increase the overlap between chunks
# **E.** Use a smaller embedding model

# %%
answer(11)
# Out:
#   <details>
#   <summary><b>Q11 - Click to reveal answer</b></summary>
#   <p><b>Answer: A, B</b></p>
#   <p><b>Explanation:</b> Increasing chunk size (A) means fewer chunks per document, reducing total record count. Decreasing overlap (B) reduces the number of chunks generated at boundaries. Both reduce the total number of embeddings stored. Decreasing chunk size (C) would increase record count. Increasing overlap (D) would also increase record count. Using a smaller embedding model (E) reduces vector dimensions, not record count—the number of vectors (rows) stays the same.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/generative-ai/vector-search" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ---
#
# ### Q12.
#
# A Generative AI Engineer is creating an LLM-based application. The documents for its retriever have been chunked to a maximum of 512 tokens each. The Generative AI Engineer knows that cost and latency are more important than quality for this application. They have several context length levels to choose from.
#
# Which will fulfill their need?
#
# **A.** context length 512: smallest model is 0.13GB and embedding dimension 384
# **B.** context length 514: smallest model is 0.44GB and embedding dimension 768
# **C.** context length 2048: smallest model is 11GB and embedding dimension 2560
# **D.** context length 32768: smallest model is 14GB and embedding dimension 4096

# %%
answer(12)
# Out:
#   <details>
#   <summary><b>Q12 - Click to reveal answer</b></summary>
#   <p><b>Answer: A</b></p>
#   <p><b>Explanation:</b> The chunks are 512 tokens, so a model with context length 512 is sufficient. The smallest model (0.13GB, 384 dimensions) prioritizes cost and latency over quality, which is exactly what the question asks for. Larger models (B: 0.44GB, C: 11GB, D: 14GB) offer better quality but higher cost and latency. Since cost and latency are more important than quality, choose the smallest model whose context length covers the chunk size.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/generative-ai/vector-search" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ---
#
# ### Q13.
#
# A Generative AI Engineer working for an online retailer is attempting to improve their search functionality with vector search plus metadata filtering. Searches can total as many as 80 per second and latency is their most critical metric. They don't mind up front development costs if it improves accuracy without harming latency. The inventory consists of 100 million items nationwide.
#
# How should the engineer set this up?
#
# **A.** Leverage GTE Large embedding model, use standard vector search with hybrid search and reranking turned on.
# **B.** Leverage GTE Large embedding model, use storage optimized vector search with hybrid search and reranking turned on.
# **C.** Fine tune a custom embedding model, use standard vector search, keep hybrid search and reranking off.
# **D.** Fine tune a custom embedding model, use storage optimized vector search, keep hybrid search and reranking off.

# %%
answer(13)
# Out:
#   <details>
#   <summary><b>Q13 - Click to reveal answer</b></summary>
#   <p><b>Answer: B</b></p>
#   <p><b>Explanation:</b> For 100 million items, storage-optimized vector search is designed for large-scale indexes. GTE Large provides high-quality embeddings. Hybrid search + reranking improves accuracy. The question states latency is critical and they don't mind upfront costs, so the best accuracy setup (storage-optimized + GTE Large + hybrid + reranking) is correct. Standard vector search (A) may not handle 100M items as efficiently. Fine-tuning a custom model (C, D) adds complexity without clear benefit, and turning off hybrid/reranking reduces accuracy.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/generative-ai/vector-search" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ---
#
# ### Q14.
#
# You notice high retrieval latency from your Vector Search index. Chunks are 2,500 tokens and documents contain mixed topics. What is the most impactful remediation?
#
# **A.** Increase chunk size further to reduce index size
# **B.** Introduce semantic chunking with smaller, coherent chunks and add metadata filters for doc_type and product
# **C.** Remove metadata to simplify the index
# **D.** Use only keyword search because vector search is slower by default

# %%
answer(14)
# Out:
#   <details>
#   <summary><b>Q14 - Click to reveal answer</b></summary>
#   <p><b>Answer: B</b></p>
#   <p><b>Explanation:</b> Smaller, semantically coherent chunks reduce noise and improve retrieval precision. Metadata filters (doc_type, product) narrow the search space, reducing latency by avoiding irrelevant chunks. Increasing chunk size (A) makes chunks noisier and doesn't help with mixed topics. Removing metadata (C) removes useful filtering capability. Using keyword-only search (D) loses semantic matching, which is the primary advantage of vector search.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/generative-ai/vector-search" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ---
#
# ### Q15.
#
# Your RAG system sometimes returns irrelevant context due to ambiguous queries. You want to improve retrieval without changing the model. What should you try?
#
# **A.** Hybrid retrieval combining vector similarity with BM25 or metadata filters
# **B.** Increase temperature to encourage variety
# **C.** Remove metadata to reduce conflicts
# **D.** Use only embeddings trained on code

# %%
answer(15)
# Out:
#   <details>
#   <summary><b>Q15 - Click to reveal answer</b></summary>
#   <p><b>Answer: A</b></p>
#   <p><b>Explanation:</b> Hybrid retrieval combines vector similarity (semantic) with BM25 (lexical/keyword) matching, improving recall for ambiguous queries. Vector search alone may miss exact-term matches, while BM25 catches keyword matches. The combination covers both semantic and lexical gaps. Increasing temperature (B) affects generation, not retrieval. Removing metadata (C) removes useful filters. Code-trained embeddings (D) are irrelevant to general query ambiguity.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/generative-ai/vector-search" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ---
#
# ### Q16.
#
# You notice retrieval quality degrades after frequent schema changes in source tables. Some embeddings don't match expected vector dimensions. What's the most robust fix?
#
# **A.** Re-embed only new rows
# **B.** Enforce a contract for embedding model + vector dimension; store model metadata alongside vectors; rebuild index when changing model
# **C.** Convert vectors to the new dimension by zero-padding
# **D.** Switch to keyword-only search

# %%
answer(16)
# Out:
#   <details>
#   <summary><b>Q16 - Click to reveal answer</b></summary>
#   <p><b>Answer: B</b></p>
#   <p><b>Explanation:</b> Enforce a contract that stores the embedding model name and vector dimensions alongside the vectors. When the model changes (producing different dimensions), rebuild the entire index—existing embeddings are incompatible. Zero-padding (C) produces garbage vectors that destroy retrieval quality because the new dimensions have no semantic meaning. Re-embedding only new rows (A) creates dimension mismatches between old and new vectors. Switching to keyword-only (D) abandons semantic search entirely.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/generative-ai/vector-search" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ---
#
# ### Q17.
#
# After adding richer context, the model sometimes exceeds token limits and truncates answers. What's the best immediate mitigation?
#
# **A.** Increase temperature
# **B.** Apply retrieval budget: limit number/size of chunks by dynamic relevance, compress or summarize context before generation
# **C.** Use a smaller model
# **D.** Remove system prompts

# %%
answer(17)
# Out:
#   <details>
#   <summary><b>Q17 - Click to reveal answer</b></summary>
#   <p><b>Answer: B</b></p>
#   <p><b>Explanation:</b> A retrieval budget limits the number and size of chunks fed to the LLM based on dynamic relevance scores. If you retrieve 10 chunks but only have token budget for 5, keep the top-5 by relevance. Context compression (summarizing retrieved context before generation) also reduces token usage. Both prevent exceeding the model's context window. Increasing temperature (A) doesn't help. Using a smaller model (C) changes quality. Removing system prompts (D) removes useful guidance.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/large-language-models/rag-concept" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ---
#
# ### Q18.
#
# After changing the response generating LLM in a RAG pipeline from GPT-4 to a model with a shorter context length that the company self-hosts, the Generative AI Engineer is getting an error that the context exceeds the model's limit. What TWO solutions should the Generative AI Engineer implement without changing the response generating model? (Choose two.)
#
# **A.** Use a smaller embedding model to generate embeddings
# **B.** Reduce the maximum output tokens of the new model
# **C.** Decrease the chunk size of embedded documents
# **D.** Reduce the number of records retrieved from the vector database
# **E.** Retrain the response generating model using ALiBi

# %%
answer(18)
# Out:
#   <details>
#   <summary><b>Q18 - Click to reveal answer</b></summary>
#   <p><b>Answer: C, D</b></p>
#   <p><b>Explanation:</b> Decreasing chunk size (C) reduces the total context per retrieval—each chunk is smaller. Reducing the number of retrieved records (lower k) (D) also reduces context length. Both cut context length without changing the response-generating model. Using a smaller embedding model (A) changes vector dimensions, not context length. Reducing output tokens (B) doesn't affect input context. Retraining with ALiBi (E) is not practical and doesn't address context window size.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/large-language-models/rag-concept" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ---
#
# ### Q19.
#
# A Generative AI Engineer has successfully ingested unstructured documents and chunked them by document sections. They would like to store the chunks in a Vector Search index. The current format of the dataframe has two columns: (i) original document file name (ii) an array of text chunks for each document.
#
# What is the most performant way to store this dataframe?
#
# **A.** Split the data into train and test set, create a unique identifier for each document, then save to a Delta table
# **B.** Flatten the dataframe to one chunk per row, create a unique identifier for each row, and save to a Delta table
# **C.** First create a unique identifier for each document, then save to a Delta table
# **D.** Store each chunk as an independent JSON file in Unity Catalog Volume

# %%
answer(19)
# Out:
#   <details>
#   <summary><b>Q19 - Click to reveal answer</b></summary>
#   <p><b>Answer: B</b></p>
#   <p><b>Explanation:</b> Vector Search requires one row per chunk with a unique primary key. Flattening the dataframe from (document, array_of_chunks) to one chunk per row ensures each chunk is individually retrievable and indexable. Storing as JSON files in UC volumes (D) is not performant for vector search. Splitting into train/test (A) is irrelevant for indexing. Creating a single ID per document (C) means only one chunk per document would be retrievable.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/generative-ai/vector-search" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ## Hours 4-5: Agents, Tools & Multi-Agent (Demo 4, 5, 6)
#
# ---

# %% [markdown]
# ### Q20.
#
# You added tool/function-calling to let the model query an internal REST API for order status. Sometimes the LLM hallucinates tool parameters. How can you improve reliability?
#
# **A.** Allow free-form text for tool arguments
# **B.** Provide JSON schemas for tool inputs and validate before execution; include few-shot examples of correct tool usage
# **C.** Increase temperature
# **D.** Remove function calling and hardcode API calls

# %%
answer(20)
# Out:
#   <details>
#   <summary><b>Q20 - Click to reveal answer</b></summary>
#   <p><b>Answer: B</b></p>
#   <p><b>Explanation:</b> JSON schemas constrain the model's tool-call output to valid parameters—the model must produce values matching the schema types and constraints. Validation catches errors before execution, preventing API failures. Few-shot examples guide correct tool usage patterns by showing the model what good calls look like. Free-form text (A) increases hallucination risk. Increasing temperature (C) worsens reliability. Removing function calling (D) loses the dynamic capability entirely.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/generative-ai/agent-framework/tool-use" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ---
#
# ### Q21.
#
# Your RAG answers include stale prices for SKUs that change daily. You already re-embed content nightly. What else should you do?
#
# **A.** Add a tool/function call to fetch live pricing for cited SKUs and instruct the model to prioritize tool data over retrieved chunks
# **B.** Increase vector dimension
# **C.** Disable retrieval and use the tool only
# **D.** Reduce k in retrieval

# %%
answer(21)
# Out:
#   <details>
#   <summary><b>Q21 - Click to reveal answer</b></summary>
#   <p><b>Answer: A</b></p>
#   <p><b>Explanation:</b> For rapidly changing data like daily prices, a tool/function call to the live source is more reliable than nightly re-embedding. The system prompt should instruct the model to prioritize tool-fetched data over retrieved chunks for current pricing. This ensures the model always has the latest price, not a cached version from last night's embedding. Increasing vector dimensions (B) doesn't solve data staleness. Disabling retrieval (C) loses the knowledge base context. Reducing k (D) reduces context without solving the price freshness problem.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/generative-ai/agent-framework/tool-use" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ---
#
# ### Q22.
#
# A Generative AI Engineer is creating an LLM-powered application that will need access to up-to-date news articles and stock prices. The design requires the use of stock prices which are stored in Delta tables and finding the latest relevant news articles by searching the internet.
#
# How should the Generative AI Engineer architect their LLM system?
#
# **A.** Use an LLM to summarize the latest news articles and lookup stock tickers from the summaries to find stock prices.
# **B.** Query the Delta table for volatile stock prices and use an LLM to generate a search query to investigate potential causes of the stock volatility.
# **C.** Download and store news articles and stock price information in a vector store. Use a RAG architecture to retrieve and generate at runtime.
# **D.** Create an agent with tools for SQL querying of Delta tables and web searching, provide retrieved values to an LLM for generation of response.

# %%
answer(22)
# Out:
#   <details>
#   <summary><b>Q22 - Click to reveal answer</b></summary>
#   <p><b>Answer: D</b></p>
#   <p><b>Explanation:</b> An agent with tools (SQL querying for Delta tables to get stock prices, web search for latest news) can access real-time data on demand. This is the most flexible architecture. RAG alone (C) cannot handle live stock prices or fresh news that hasn't been indexed yet. Summarizing news first (A) loses the ability to look up specific stock data. Querying Delta then searching (B) is partial but doesn't provide a unified response to the user.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/generative-ai/agent-framework/" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ---
#
# ### Q23.
#
# A Generative AI Engineer received the following business requirements for an external chatbot. The chatbot needs to know what types of questions the user asks and routes to appropriate models to answer the questions. For example, the user might ask about upcoming event details. Another user might ask about purchasing tickets for a particular event.
#
# What is an ideal workflow for such a chatbot?
#
# **A.** The chatbot should only look at previous event information
# **B.** There should be two different chatbots handling different types of user queries.
# **C.** The chatbot should be implemented as a multi-step LLM workflow. First, identify the type of question asked, then route the question to the appropriate model. If it's an upcoming event question, send the query to a text-to-SQL model. If it's about ticket purchasing, the customer should be redirected to a payment platform.
# **D.** The chatbot should only process payments

# %%
answer(23)
# Out:
#   <details>
#   <summary><b>Q23 - Click to reveal answer</b></summary>
#   <p><b>Answer: C</b></p>
#   <p><b>Explanation:</b> A multi-step LLM workflow with question-type identification and routing is the most flexible approach. First, identify what type of question the user is asking (event details vs. ticket purchasing), then route to the appropriate model or action. For event questions, send to a text-to-SQL model. For ticket purchasing, redirect to a payment platform. This handles different question types with appropriate responses. Having two separate chatbots (B) is less flexible. Only looking at event info (A) or only processing payments (D) are too narrow.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/generative-ai/agent-framework/" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ## Hour 6: Security, Governance & Evaluation (Demo 4, 7)
#
# ---

# %% [markdown]
# ### Q24.
#
# You're onboarding a multi-tenant RAG app across business units with strict data separation. What's the primary control to enforce isolation of embeddings and source documents?
#
# **A.** Model endpoint tokens
# **B.** Unity Catalog permissions on source tables and vector indexes, + service principals scoped per tenant
# **C.** Notebook ACLs only
# **D.** Row-level security in notebooks via Python conditionals

# %%
answer(24)
# Out:
#   <details>
#   <summary><b>Q24 - Click to reveal answer</b></summary>
#   <p><b>Answer: B</b></p>
#   <p><b>Explanation:</b> Unity Catalog provides table-level and column-level permissions on source tables and vector indexes. Scoped service principals per tenant ensure each tenant only accesses their own data and indexes. This is the primary governance control for multi-tenant isolation. Model endpoint tokens (A) control API access, not data isolation. Notebook ACLs (C) don't govern vector indexes or source tables. Row-level security in notebooks via Python (D) is not enforceable at the platform level.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/data-governance/unity-catalog/" target="_blank">Databricks Documentation</a></p>
#   </details>

# %% [markdown]
# ---
#
# ### Q25.
#
# Your legal team requires removal of sensitive PII in prompts and model outputs. You want minimal developer friction. What should you deploy?
#
# **A.** Manual developer checklist
# **B.** Pre/post-processing policies that redact PII at the gateway or serving layer, with audit logs
# **C.** Remove logs entirely
# **D.** Ask users not to enter PII

# %%
answer(25)

# %% [markdown]
# ---
#
# ### Q28.
#
# You need to roll out a new model version but want a safe migration with minimal risk to production users. What should you do?
#
# **A.** Replace the model immediately
# **B.** Run shadow or canary traffic for the new version, monitor metrics and feedback, then gradually increase traffic
# **C.** Force all users to test in dev first
# **D.** Disable logging during rollout

# %% [markdown]
# ---
#
# ### Q27.
#
# You're asked to launch an A/B test of two prompts for the same endpoint to reduce hallucinations. You need traffic splitting and win-rate measurement. What's the best plan?
#
# **A.** Manually alternate between prompts in the notebook
# **B.** Use a gateway or routing layer to split traffic between prompt variants, and log outcomes for statistical comparison
# **C.** Launch both in separate workspaces and compare logs by hand
# **D.** Switch models instead of prompts

# %%
answer(28)

# %%
answer(31)

# %% [markdown]
# ---
#
# ### Q30.
#
# The team wants to evaluate end-to-end task success (not just BLEU/ROUGE) for a claims-processing agent that calls multiple tools. What should you implement?
#
# **A.** Only measure token counts
# **B.** Task-level success metrics with golden tasks, plus step-level traces for tool calls and failures
# **C.** Per-token probabilities
# **D.** Context window utilization

# %% [markdown]
# ---
#
# ### Q32.
#
# A Generative AI Engineer has created a RAG application which can help employees retrieve answers from an internal knowledge base. The prototype is working with positive feedback. Now the engineer wants to formally evaluate the system's performance and understand where to focus improvement efforts.
#
# How should the Generative AI Engineer evaluate the system?
#
# **A.** Use cosine similarity score to comprehensively evaluate the quality of the final generated answers.
# **B.** Curate a dataset that can test the retrieval and generation components of the system separately. Use built-in evaluation metrics to perform the evaluation on the retrieval and generation components.
# **C.** Benchmark multiple LLMs with the same data and pick the best LLM for the job.
# **D.** Use an LLM-as-a-judge to evaluate the quality of the final answers generated.

# %%
answer(30)

# %% [markdown]
# ---
#
# ### Q26.
#
# The security team wants visibility into who called which model, with what data classes, and when. What should you enable?
#
# **A.** Random sampling of prompts in notebooks
# **B.** Centralized access logs and lineage across data sources and serving endpoints, with Unity Catalog tags for sensitive data
# **C.** Save logs to a local file
# **D.** Disable access to reduce risk

# %%
answer(32)
# Out:
#   <details>
#   <summary><b>Q32 - Click to reveal answer</b></summary>
#   <p><b>Answer: B</b></p>
#   <p><b>Explanation:</b> Separating retrieval and generation evaluation pinpoints which component needs improvement. A curated dataset with dedicated metrics for each component (retrieval metrics like recall@k and precision@k, generation metrics like faithfulness and relevance) is the most systematic approach. Cosine similarity alone (A) only measures vector similarity, not generation quality. Benchmarking LLMs (C) doesn't evaluate the RAG system itself. LLM-as-judge (D) evaluates final answers but doesn't isolate which component (retrieval vs. generation) is underperforming.</p>
#   <p>📖 <a href="https://docs.databricks.com/aws/en/generative-ai/llm-evaluation/" target="_blank">Databricks Documentation</a></p>
#   </details>

# %%
answer(26)

# %% [markdown]
# ---
#
# ### Q29.
#
# A Generative AI Engineer is responsible for evaluating a customer-support RAG assistant. Four domain experts review sampled answers each week using dimensions such as factual accuracy, completeness, and usefulness. After several rounds, the engineer notices that expert ratings vary widely for the same responses, making the evaluation data unreliable.
#
# What should the engineer do?
#
# **A.** Use an LLM-as-a-judge to rescore past and future responses, and treat the model-generated ratings as the primary source of truth instead of reconciling expert disagreement.
# **B.** Define clear rubrics, calibrate SMEs on the criteria, and use the aligned judgments for consistent agent evaluation.
# **C.** Average the scores from all domain experts for each response and use the blended score directly as the definitive benchmark for model tuning.
# **D.** Build the benchmark only from responses where all experts already agree, and exclude disputed cases from the evaluation set to improve consistency.

# %%
answer(29)

# %% [markdown]
# ---
#
# ### Q31.
#
# A Generative AI Engineer is building a system which will answer questions on latest stock news articles. Which will NOT help with ensuring the outputs are relevant to financial news?
#
# **A.** Implement a comprehensive guardrail framework that includes policies for content filters tailored to the finance sector.
# **B.** Increase the compute to improve processing speed of questions to allow greater relevancy analysis
# **C.** Implement a profanity filter to screen out offensive language.
# **D.** Incorporate manual reviews to correct any problematic outputs prior to sending to the users.

# %%
answer(27)

# %% [markdown]
# ## Questions Removed (Not Covered in Module 5A Demos)
#
# The following questions from the Sample Questions notebook were **excluded** because their topics are NOT demonstrated in any Module 5A demo. Most belong to Module 5B (MLflow/ML lifecycle) or Module 6B (deployment/governance) of the official curriculum.
#
# ---
#
# ### Removed: Model Deployment & Serving Infrastructure (7 questions)
#
# | Question | Why Removed | Official Module |
# |---|---|---|
# | Prompt optimization (templates, caching) | Not discussed in any demo — Demo 2 covers temperature, not prompt compression | 6B |
# | Batch inference for cost reduction | Not discussed — Demo 2 mentions “Deploy” as a stage name only | 6B |
# | Batch inference for structured output | Same — no batch inference demo | 6B |
# | Model Serving autoscaling | Not discussed in any demo | 6B |
# | Warm instances / scale-to-zero | Not discussed in any demo | 6B |
# | Model deployment workflow (log, register, serve) | Not discussed — this is MLflow-specific (removed from Module 5A) | 5B |
# | Provisioned throughput vs pay-per-token | Not discussed in any demo | 6B |
#
# ### Removed: Model Knowledge (2 questions)
#
# | Question | Why Removed |
# |---|---|
# | CodeLlama for code generation | Demo 2 compares Llama models generically, but CodeLlama specifically is never mentioned |
# | DBRX for large context window | Not mentioned in any demo |
#
# ### Removed: Other Topics Not in Demos (5 questions)
#
# | Question | Why Removed |
# |---|---|
# | Chatbot engagement metric (diversity) | Not discussed in any demo |
# | Streaming RAG architecture (Bronze → Silver) | Streaming is a Module 4 topic; Demo 3 covers AI Search index creation, not streaming pipelines |
# | Multilingual RAG | Demo 2 covers ai_translate and Demo 3 covers embeddings, but multilingual embedding strategies aren't discussed |
# | Distributed embedding generation with Spark | Demo 3 covers embeddings but not Spark-based distributed generation specifically |
# | Production monitoring with MRR/Recall@k | Demo 7 covers LLM-as-judge conceptually, but specific retrieval metrics (MRR, Recall@k) aren't discussed |
#
# ---
#
# ### Syllabus Headings Now Backed by Demo Content
#
# All previously gap topics now have demonstrations in their respective demo notebooks:
#
# | Syllabus Topic | Demo Coverage | Status |
# |---|---|---|
# | 2.10 - Deploy stage | Demo 2: ai_query on two deployed models, SHOW CATALOGS, 5-stage platform recap | ✅ Demo added |
# | 2.9 - Compound AI Systems | Demo 2: chains ai_mask -> ai_classify -> ai_summarize; later demos cover retrieval/tools | ✅ Already demoed |
# | 4.7 - AI Gateway | Demo 4: hands-on PII guardrails (ai_mask), traffic splitting, rate limiting, usage tracking | ✅ Demo added |
# | 6.1 - Platform Map | Demo 7: same question across 5 platform tools (Playground, Genie, Agent Framework, Agent Bricks, Model Serving) | ✅ Already demoed |
# | 6.2 - Adoption Roadmap | Demo 7: foundation-first governed data, AI functions, LLM-as-judge evaluation, role mapping | ✅ Demo added |

# %%
# ============================================================================
# REUSABLE ANSWER FUNCTION - Run this cell FIRST before running any answer cell
# ============================================================================

from IPython.display import display, HTML

ANSWERS = {
  1: {"answer": "D - Summarization",
      "explain": "Condensing a paragraph into a single-sentence gist that captures intent is a summarization task. The LLM takes a longer input and produces a shorter version that captures the essential meaning. text2text Generation (A) is broader and includes translation, not just condensation. Sentencizer (B) splits text into sentences, it doesn't summarize. Text Classification (C) categorizes text into labels, it doesn't produce a summary.",
      "doc": "https://docs.databricks.com/aws/en/large-language-models/concept-ai-functions"},
  2: {"answer": "B",
      "explain": "Normalizing the source document's tone does NOT help because the LLM generates its own text—the source document's tone is irrelevant to the output style. The LLM reads the content, not the style, of the source. Providing explicit prompt instructions (A), including few-shot examples (C), and fine-tuning (D) are all valid approaches to control the LLM's output tone and style.",
      "doc": "https://docs.databricks.com/aws/en/large-language-models/concept-ai-functions"},
  3: {"answer": "B",
      "explain": "The application needs structured delivery date data keyed by transaction_id. A feature store table provides exact lookup for specific transactions, while a vector store is for semantic search over unstructured content. Shipping policies in a vector store (A) would return general policy text, not specific delivery dates for specific orders. Fine-tuning (C) would require constant retraining. Adding 14 days (D) is unreliable as actual delivery times vary by location and shipping method.",
      "doc": "https://docs.databricks.com/aws/en/machine-learning/feature-store/"},
  4: {"answer": "C - pytesseract",
      "explain": "pytesseract is an OCR wrapper for the Tesseract engine that extracts text from scanned images (.jpeg, .png) with minimal code. beautifulsoup (A) is an HTML parser, not an OCR tool. scrapy (B) is a web scraping framework. pyquery (D) is a jQuery-like HTML querying library. For scanned images specifically, pytesseract is the correct choice. In production on Databricks, you would use ai_parse_document instead, but pytesseract is the correct third-party library answer.",
      "doc": "https://docs.databricks.com/aws/en/large-language-models/concept-ai-functions"},
  5: {"answer": "A",
      "explain": "RAG grounds responses in retrieved facts from a curated Vector Search index, reducing hallucinations. Including citations in the prompt adds traceability and allows verification. Increasing temperature (B) would increase randomness and likely worsen hallucinations. Switching to a larger model (C) doesn't solve hallucination—it may hallucinate just as confidently. Removing system prompts (D) removes useful guidance that keeps the model on track.",
      "doc": "https://docs.databricks.com/aws/en/large-language-models/rag-concept"},
  6: {"answer": "B",
      "explain": "Retrieval gating requires a minimum relevance score before using retrieved context. If the best chunk's similarity is below a threshold, the system should refuse to answer ('I don't know') instead of guessing. A refusal policy in the system prompt explicitly instructs the model to say 'I don't know' when evidence is weak. Lowering temperature (A) reduces randomness but doesn't guarantee grounded answers. Increasing top_p (C) increases diversity, worsening the problem. Using only embeddings (D) without prompts removes the instruction to refuse.",
      "doc": "https://docs.databricks.com/aws/en/large-language-models/rag-concept"},
  7: {"answer": "B",
      "explain": "Table-aware extraction preserves the structure that plain OCR or text extraction loses. Tables in PDFs have rows, columns, and cell relationships that are destroyed when flattened to text. Storing both text and structured table data with metadata enables accurate retrieval of tabular content. Ignoring tables (A) loses critical information. Increasing chunk size to include entire tables (C) dilutes relevance and may exceed token limits. Using only OCR text (D) loses table structure entirely.",
      "doc": "https://docs.databricks.com/aws/en/large-language-models/concept-ai-functions"},
  8: {"answer": "C",
      "explain": "A system prompt instruction to refuse unrelated questions is the simplest and most effective approach among the options. It directly instructs the model to stay on topic and decline off-topic questions. Keeping all articles (A) pollutes the index with irrelevant content. Telling the model all content is about SnoPenAI (B) is factually wrong and could cause hallucination. Consolidating into a single chunk (D) loses granularity and makes retrieval less precise.",
      "doc": "https://docs.databricks.com/aws/en/large-language-models/rag-concept"},
  9: {"answer": "A",
      "explain": "The correct RAG flow is: (1) embed the user's query using the embedding model, (2) search the vector index for similar chunks using the embedded query, (3) augment the prompt with retrieved context, (4) generate the response with the LLM. Option B has the wrong order (context before search). Option C starts with the LLM. Option D also starts with the LLM.",
      "doc": "https://docs.databricks.com/aws/en/large-language-models/rag-concept"},
  10: {"answer": "C - unstructured",
      "explain": "The unstructured library handles mixed-format PDFs (containing both text and images) with minimal code. flask (A) is a web framework, not a document processing tool. beautifulsoup (B) is for HTML parsing. numpy (D) is for numerical computing. For PDFs with mixed text and images, unstructured is the correct choice. For scanned images only (.jpeg, .png), pytesseract would be better. In production on Databricks, you would use ai_parse_document instead.",
      "doc": "https://docs.databricks.com/aws/en/large-language-models/concept-ai-functions"},
  11: {"answer": "A, B",
      "explain": "Increasing chunk size (A) means fewer chunks per document, reducing total record count. Decreasing overlap (B) reduces the number of chunks generated at boundaries. Both reduce the total number of embeddings stored. Decreasing chunk size (C) would increase record count. Increasing overlap (D) would also increase record count. Using a smaller embedding model (E) reduces vector dimensions, not record count—the number of vectors (rows) stays the same.",
      "doc": "https://docs.databricks.com/aws/en/generative-ai/vector-search"},
  12: {"answer": "A",
      "explain": "The chunks are 512 tokens, so a model with context length 512 is sufficient. The smallest model (0.13GB, 384 dimensions) prioritizes cost and latency over quality, which is exactly what the question asks for. Larger models (B: 0.44GB, C: 11GB, D: 14GB) offer better quality but higher cost and latency. Since cost and latency are more important than quality, choose the smallest model whose context length covers the chunk size.",
      "doc": "https://docs.databricks.com/aws/en/generative-ai/vector-search"},
  13: {"answer": "B",
      "explain": "For 100 million items, storage-optimized vector search is designed for large-scale indexes. GTE Large provides high-quality embeddings. Hybrid search + reranking improves accuracy. The question states latency is critical and they don't mind upfront costs, so the best accuracy setup (storage-optimized + GTE Large + hybrid + reranking) is correct. Standard vector search (A) may not handle 100M items as efficiently. Fine-tuning a custom model (C, D) adds complexity without clear benefit, and turning off hybrid/reranking reduces accuracy.",
      "doc": "https://docs.databricks.com/aws/en/generative-ai/vector-search"},
  14: {"answer": "B",
      "explain": "Smaller, semantically coherent chunks reduce noise and improve retrieval precision. Metadata filters (doc_type, product) narrow the search space, reducing latency by avoiding irrelevant chunks. Increasing chunk size (A) makes chunks noisier and doesn't help with mixed topics. Removing metadata (C) removes useful filtering capability. Using keyword-only search (D) loses semantic matching, which is the primary advantage of vector search.",
      "doc": "https://docs.databricks.com/aws/en/generative-ai/vector-search"},
  15: {"answer": "A",
      "explain": "Hybrid retrieval combines vector similarity (semantic) with BM25 (lexical/keyword) matching, improving recall for ambiguous queries. Vector search alone may miss exact-term matches, while BM25 catches keyword matches. The combination covers both semantic and lexical gaps. Increasing temperature (B) affects generation, not retrieval. Removing metadata (C) removes useful filters. Code-trained embeddings (D) are irrelevant to general query ambiguity.",
      "doc": "https://docs.databricks.com/aws/en/generative-ai/vector-search"},
  16: {"answer": "B",
      "explain": "Enforce a contract that stores the embedding model name and vector dimensions alongside the vectors. When the model changes (producing different dimensions), rebuild the entire index—existing embeddings are incompatible. Zero-padding (C) produces garbage vectors that destroy retrieval quality because the new dimensions have no semantic meaning. Re-embedding only new rows (A) creates dimension mismatches between old and new vectors. Switching to keyword-only (D) abandons semantic search entirely.",
      "doc": "https://docs.databricks.com/aws/en/generative-ai/vector-search"},
  17: {"answer": "B",
      "explain": "A retrieval budget limits the number and size of chunks fed to the LLM based on dynamic relevance scores. If you retrieve 10 chunks but only have token budget for 5, keep the top-5 by relevance. Context compression (summarizing retrieved context before generation) also reduces token usage. Both prevent exceeding the model's context window. Increasing temperature (A) doesn't help. Using a smaller model (C) changes quality. Removing system prompts (D) removes useful guidance.",
      "doc": "https://docs.databricks.com/aws/en/large-language-models/rag-concept"},
  18: {"answer": "C, D",
      "explain": "Decreasing chunk size (C) reduces the total context per retrieval—each chunk is smaller. Reducing the number of retrieved records (lower k) (D) also reduces context length. Both cut context length without changing the response-generating model. Using a smaller embedding model (A) changes vector dimensions, not context length. Reducing output tokens (B) doesn't affect input context. Retraining with ALiBi (E) is not practical and doesn't address context window size.",
      "doc": "https://docs.databricks.com/aws/en/large-language-models/rag-concept"},
  19: {"answer": "B",
      "explain": "Vector Search requires one row per chunk with a unique primary key. Flattening the dataframe from (document, array_of_chunks) to one chunk per row ensures each chunk is individually retrievable and indexable. Storing as JSON files in UC volumes (D) is not performant for vector search. Splitting into train/test (A) is irrelevant for indexing. Creating a single ID per document (C) means only one chunk per document would be retrievable.",
      "doc": "https://docs.databricks.com/aws/en/generative-ai/vector-search"},
  20: {"answer": "B",
      "explain": "JSON schemas constrain the model's tool-call output to valid parameters—the model must produce values matching the schema types and constraints. Validation catches errors before execution, preventing API failures. Few-shot examples guide correct tool usage patterns by showing the model what good calls look like. Free-form text (A) increases hallucination risk. Increasing temperature (C) worsens reliability. Removing function calling (D) loses the dynamic capability entirely.",
      "doc": "https://docs.databricks.com/aws/en/generative-ai/agent-framework/tool-use"},
  21: {"answer": "A",
      "explain": "For rapidly changing data like daily prices, a tool/function call to the live source is more reliable than nightly re-embedding. The system prompt should instruct the model to prioritize tool-fetched data over retrieved chunks for current pricing. This ensures the model always has the latest price, not a cached version from last night's embedding. Increasing vector dimensions (B) doesn't solve data staleness. Disabling retrieval (C) loses the knowledge base context. Reducing k (D) reduces context without solving the price freshness problem.",
      "doc": "https://docs.databricks.com/aws/en/generative-ai/agent-framework/tool-use"},
  22: {"answer": "D",
      "explain": "An agent with tools (SQL querying for Delta tables to get stock prices, web search for latest news) can access real-time data on demand. This is the most flexible architecture. RAG alone (C) cannot handle live stock prices or fresh news that hasn't been indexed yet. Summarizing news first (A) loses the ability to look up specific stock data. Querying Delta then searching (B) is partial but doesn't provide a unified response to the user.",
      "doc": "https://docs.databricks.com/aws/en/generative-ai/agent-framework/"},
  23: {"answer": "C",
      "explain": "A multi-step LLM workflow with question-type identification and routing is the most flexible approach. First, identify what type of question the user is asking (event details vs. ticket purchasing), then route to the appropriate model or action. For event questions, send to a text-to-SQL model. For ticket purchasing, redirect to a payment platform. This handles different question types with appropriate responses. Having two separate chatbots (B) is less flexible. Only looking at event info (A) or only processing payments (D) are too narrow.",
      "doc": "https://docs.databricks.com/aws/en/generative-ai/agent-framework/"},
  24: {"answer": "B",
      "explain": "Unity Catalog provides table-level and column-level permissions on source tables and vector indexes. Scoped service principals per tenant ensure each tenant only accesses their own data and indexes. This is the primary governance control for multi-tenant isolation. Model endpoint tokens (A) control API access, not data isolation. Notebook ACLs (C) don't govern vector indexes or source tables. Row-level security in notebooks via Python (D) is not enforceable at the platform level.",
      "doc": "https://docs.databricks.com/aws/en/data-governance/unity-catalog/"},
  25: {"answer": "B",
      "explain": "Gateway or serving-layer PII policies automate redaction without requiring developers to modify each prompt individually. Pre-processing redacts PII from inputs before they reach the model, post-processing redacts PII from outputs before they reach the user. Audit logs provide compliance traceability. Manual checklists (A) are error-prone and don't scale. Removing logs entirely (C) eliminates auditability. Asking users not to enter PII (D) is unreliable.",
      "doc": "https://docs.databricks.com/aws/en/generative-ai/ai-gateway/"},
  26: {"answer": "B",
      "explain": "Centralized access logs and lineage across data sources and serving endpoints provide full visibility into who called which model, with what data, and when. Unity Catalog tags for sensitive data enable governance policies and automated access controls. This gives the security team a comprehensive audit trail. Random sampling (A) misses most activity. Saving to a local file (C) is not centralized or scalable. Disabling access (D) reduces risk but also eliminates productivity.",
      "doc": "https://docs.databricks.com/aws/en/data-governance/unity-catalog/"},
  27: {"answer": "B",
      "explain": "AI Gateway or a routing layer enables programmatic traffic splitting between prompt variants. You can route 50% of traffic to prompt A and 50% to prompt B. Logging outcomes allows statistical comparison of win rates (e.g., which prompt produces fewer hallucinations). Manual alternation (A) is not scalable or statistically valid. Using separate workspaces (C) is impractical. Switching models (D) tests a different variable than prompt quality.",
      "doc": "https://docs.databricks.com/aws/en/generative-ai/ai-gateway/"},
  28: {"answer": "B",
      "explain": "Shadow or canary deployment routes a small percentage of traffic (e.g., 5%) to the new model version. Monitoring metrics and user feedback before gradually increasing traffic (5% -> 10% -> 50% -> 100%) minimizes risk to production users. If issues are detected, you can roll back immediately. Replacing immediately (A) risks all users. Forcing all users through dev (C) is impractical and doesn't test production conditions. Disabling logging (D) removes the ability to monitor the rollout.",
      "doc": "https://docs.databricks.com/aws/en/machine-learning/model-serving/"},
  29: {"answer": "B",
      "explain": "Clear rubrics and SME calibration reduce rater inconsistency. When all experts understand the criteria the same way, their judgments become aligned and reliable. This produces consistent evaluation data for tracking improvements over time. Using LLM-as-judge as the primary source (A) without reconciling expert disagreement introduces model bias. Averaging scores (C) masks disagreement rather than resolving it. Excluding disputed cases (D) biases the evaluation set toward easy cases.",
      "doc": "https://docs.databricks.com/aws/en/generative-ai/llm-evaluation/"},
  30: {"answer": "B",
      "explain": "Task-level success metrics (golden tasks) measure end-to-end outcomes for the claims-processing agent—did it successfully process the claim? Step-level traces diagnose tool call failures and intermediate steps—where did the agent go wrong? This combination captures both overall success and diagnostic detail. BLEU/ROUGE only measure text similarity, not task success. Token counts (A) and context window utilization (D) don't measure whether the task was completed successfully.",
      "doc": "https://docs.databricks.com/aws/en/generative-ai/llm-evaluation/"},
  31: {"answer": "B",
      "explain": "Increasing compute does NOT improve relevance—it only speeds up processing. Relevance is about content quality and filtering, not processing speed. Guardrails with content filters tailored to finance (A), profanity filters (C), and manual reviews (D) all directly address content quality and relevance. Compute is orthogonal to whether the output is relevant to financial news.",
      "doc": "https://docs.databricks.com/aws/en/generative-ai/ai-gateway/guardrails"},
  32: {"answer": "B",
      "explain": "Separating retrieval and generation evaluation pinpoints which component needs improvement. A curated dataset with dedicated metrics for each component (retrieval metrics like recall@k and precision@k, generation metrics like faithfulness and relevance) is the most systematic approach. Cosine similarity alone (A) only measures vector similarity, not generation quality. Benchmarking LLMs (C) doesn't evaluate the RAG system itself. LLM-as-judge (D) evaluates final answers but doesn't isolate which component (retrieval vs. generation) is underperforming.",
      "doc": "https://docs.databricks.com/aws/en/generative-ai/llm-evaluation/"},
}

def answer(qid):
  """Display an expandable answer for question Q{qid}. Run this cell, then click to expand."""
  if qid not in ANSWERS:
    display(HTML(f"<p><b>Error:</b> No answer found for Q{qid}</p>"))
    return
  a = ANSWERS[qid]
  display(HTML(f'''
  <details>
  <summary><b>Q{qid} - Click to reveal answer</b></summary>
  <p><b>Answer: {a["answer"]}</b></p>
  <p><b>Explanation:</b> {a["explain"]}</p>
  <p>📖 <a href="{a["doc"]}" target="_blank">Databricks Documentation</a></p>
  </details>
  '''))

print("✅ Answer function ready! Run any answer cell (e.g., answer(1)) to reveal answers.")
# Out:
# ✅ Answer function ready! Run any answer cell (e.g., answer(1)) to reveal answers.
